# %%
from py2neo import *
from Schema import *
from neo4j import GraphDatabase
from pickle5 import pickle
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import plotly.graph_objects as go
from sklearn.manifold import TSNE
import random
import numpy as np

def getRandomColor(n):
    colors = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(n)]
    return colors

sc = pickle.load(open('snb_schema_emailLanguage_modifiedEdgeTypeSet','rb',-1))

snb_gt_sc = pickle.load(open('schema_snb-1_all_nodes_rels_ground_truth.pickle','rb',-1))

import pickle
mb6_sc = pickle.load(open('schema_mb6_allNodesRels.pickle','rb',-1))
mb6_gt_sc = pickle.load(open('schema_mb6_ground_truth.pickle','rb',-1))
# shop_sc = pickle.load(open('shop_attr_based_schema.pkl','rb',-1))

# %%
def plot_snb(sim_matrix,title,metric=None,perplexity=30):
    x,labels = sc.nodetypeset.plotVectorizedNodes()
    snb_color_dict = {'Company':'#a6cee3','Comment':'#1f78b4','University':'#b2df8a','Tag;':'#33a02c',
                     'TagClass':'#fb9a99','Post':'#e31a1c','Country':'#fdbf6f','City':'#ff7f00',
                      'Continent':'#cab2d6','Forum':'#6a3d9a','Person':'#ffff99'}
    snb_color = []
    for l in labels:
        for k in snb_color_dict:
            if k in l:
#                 print(k)
                snb_color.append(snb_color_dict[k])
#                 mb6_color.append(k)
#     print(labels)
#     print(len(snb_color),len(labels))
    assert(len(labels)==len(snb_color))
    X_2d = None

    if metric!=None:
        x = np.array(x)
        tsne = TSNE(n_components=2, random_state=0,metric=metric,perplexity=perplexity)
        X_2d = tsne.fit_transform(x)
    else:
        sim_matrix = 1 - np.matrix(sim_matrix) #note, the argument should be distance so use 1-sim_matrix
        tsne = TSNE(n_components=2, random_state=0,metric='precomputed',perplexity=perplexity)
        X_2d = tsne.fit_transform(sim_matrix)

    layout = go.Layout(
        plot_bgcolor='rgba(0,0,0,0)'
    )
    fig = go.Figure(data=go.Scatter(x=X_2d[:, 0],
                                    y=X_2d[:, 1],
                                    mode='markers',
                                    marker_color=snb_color,
                                    text=labels),
                                    layout=layout) # hover text goes here

    fig.update_layout(title=title)
    fig.show()

# %%
def plot_mb6(sim_matrix,title,metric=None,perplexity=30):
    x,labels = mb6_sc.nodetypeset.plotVectorizedNodes()
    mb6_color_dict = {'Meta':'blue','Synapse;':'red','Segment':'black','SynapseSet':'yellow'}
    mb6_color = []
    for l in labels:
        for k in mb6_color_dict:
            if k in l:
                mb6_color.append(mb6_color_dict[k])
#                 mb6_color.append(k)
    X_2d = None

    if metric!=None:
        x = np.array(x)
        tsne = TSNE(n_components=2, random_state=0,metric=metric,perplexity=perplexity)
        X_2d = tsne.fit_transform(x)
    else:
        sim_matrix = 1 - np.matrix(sim_matrix) #note, the argument should be distance so use 1-sim_matrix
        tsne = TSNE(n_components=2, random_state=0,metric='precomputed',perplexity=perplexity)
        X_2d = tsne.fit_transform(sim_matrix)

    layout = go.Layout(
        plot_bgcolor='rgba(0,0,0,0)'
    )
    fig = go.Figure(data=go.Scatter(x=X_2d[:, 0],
                                    y=X_2d[:, 1],
                                    mode='markers',
                                    marker_color=mb6_color,
                                    text=labels),
                                    layout=layout) # hover text goes here
    fig.update_layout(title=title)
    fig.show()

# %%
sim_matrix = sc.nodetypeset.mergeByJaccardSim(return_sim_matrix=True,idf=True)
sim_matrix =  np.matrix(sim_matrix)
# sim_matrix[sim_matrix>0.5] = 1
# sim_matrix[sim_matrix<=0.5] = 0
plot_snb(sim_matrix, 'no idf, no threshold',perplexity=10)
# Out:
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="0336b038-b3bd-4b6e-bdbb-6f38dd32e99d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0336b038-b3bd-4b6e-bdbb-6f38dd32e99d")) {                    Plotly.newPlot(                        "0336b038-b3bd-4b6e-bdbb-6f38dd32e99d",                        [{"marker": {"color": ["#a6cee3", "#1f78b4", "#b2df8a", "#33a02c", "#fb9a99", "#e31a1c", "#e31a1c", "#fdbf6f", "#ff7f00", "#cab2d6", "#6a3d9a", "#ffff99"]}, "mode": "markers", "text": ["Organisation;name;url;Company;id", "length;content;locationIP;Message;id;browserUsed;creationDate;Comment", "Organisation;name;url;University;id", "name;id;url;Tag", "TagClass;name;id;url", "length;language;content;locationIP;Message;Post;id;browserUsed;creationDate", "length;locationIP;Message;Post;id;browserUsed;imageFile;creationDate", "name;Country;Place;url;id", "City;name;Place;url;id", "name;Continent;Place;url;id", "creationDate;Forum;id;title", "speaks;Person;lastName;locationIP;id;email;browserUsed;firstName;birthday;gender;creationDate"], "type": "scatter", "x": [184.4329833984375, -266.6486511230469, -192.37908935546875, -123.12287902832031, 43.03017044067383, -130.3221893310547, 213.63119506835938, 317.7738342285156, 12.447432518005371, 18.039602279663086, 375.24560546875, 118.83589935302734], "y": [-8.507643699645996, -48.931034088134766, 248.93011474609375, -251.27325439453125, 129.84764099121094, 51.0286865234375, 237.65306091308594, -167.72833251953125, -93.7249526977539, 345.5452880859375, 77.03028106689453, -276.097412109375]}],                        {"plot_bgcolor": "rgba(0,0,0,0)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"] ...

# %%
sim_matrix = mb6_sc.nodetypeset.mergeByJaccardSim(return_sim_matrix=True,idf=True)
plot_mb6(sim_matrix, 'with idf, no threshold',perplexity=20)
# Out:
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="44336baa-6a23-4ba4-b7b0-c27b7733eecb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44336baa-6a23-4ba4-b7b0-c27b7733eecb")) {                    Plotly.newPlot(                        "44336baa-6a23-4ba4-b7b0-c27b7733eecb",                        [{"marker": {"color": ["blue", "yellow", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "red", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "red", "red", "red"]}, "mode": "markers", "text": ["postHighAccuracyThreshold;superLevelRois;logo;neuroglancerMeta;roiHierarchy;postHPThreshold;preHPThreshold;totalPreCount;uuid;roiInfo;neuroglancerInfo;totalPostCount;Meta;meshHost;lastDatabaseEdit;dataset;primaryRois;latestMutationId;medulla7column_Meta;statusDefinitions", "mushroombody_SynapseSet;SynapseSet", "pre;statusLabel;status;alpha1;bodyId;mushroombody_Neuron;roiInfo;post;type;instance;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;type;instance;status;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;bodyId;size", "pre;roiInfo;post;Segment;mushroombody_Segment;alpha3;bodyId;size", "pre;statusLabel;status;cropped;bodyId;mushroombody_Neuron;roiInfo;post;type;instance;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;alpha3;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;type;instance;status;Segment;cropped;Neuron;alpha3;mushroombody_Segment;bodyId;size", "pre;statusLabel;roiInfo;post;instance;status;Segment;mushroombody_Segment;alpha3;bodyId;size", "Segment;pre;mushroombody_Segment;roiInfo;post;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;status;Segment;mushroombody_Segment;Neuron;bodyId;size", "pre;statusLabel;status;cropped;alpha1;bodyId;mushroombody_Neuron;roiInfo;post;type;instance;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;size", "pre;statusLabel;roiInfo;post;instance;status;Segment;mushroombody_Segment;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;bodyId;size", "pre;statusLabel;roiInfo;post;status;Segment;mushroombody_Segment;alpha3;bodyId;size", "pre;statusLabel;roiInfo;post;instance;status;Segment;cropped;mushroombody_Segment;bodyId;size", "pre;statusLabel;roiInfo;post;status;Segment;mushroombody_Segment;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;status;Segment;mushroombody_Segment;Neuron;alpha1;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;status;Segment;mushroombody_Segment;Neuron;alpha3;bodyId;size", "pre;statusLabel;roiInfo;post;instance;status;Segment;cropped;mushroombody_Segment;alpha3;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;cropped;Neuron;alpha3;alpha2;mushroombody_Segment;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;alpha2;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;alpha1;bodyId;size", "confidence;Synapse;alpha3;type;mushroombody_Synapse;location", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;status;Segment;cropped;Neuron;mushroombo ...

# %%
sim_matrix = mb6_sc.nodetypeset.mergeByJaccardSim(return_sim_matrix=True,idf=True)
sim_matrix = np.matrix(sim_matrix)
sim_matrix[sim_matrix>0.5] = 1
sim_matrix[sim_matrix<=0.5] = 0

plot_mb6(sim_matrix,'with idf, with 0.5 as threshold')
# Out:
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="ab281efd-f696-4d98-866c-0680f012bc24" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab281efd-f696-4d98-866c-0680f012bc24")) {                    Plotly.newPlot(                        "ab281efd-f696-4d98-866c-0680f012bc24",                        [{"marker": {"color": ["blue", "yellow", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "red", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "red", "red", "red"]}, "mode": "markers", "text": ["postHighAccuracyThreshold;superLevelRois;logo;neuroglancerMeta;roiHierarchy;postHPThreshold;preHPThreshold;totalPreCount;uuid;roiInfo;neuroglancerInfo;totalPostCount;Meta;meshHost;lastDatabaseEdit;dataset;primaryRois;latestMutationId;medulla7column_Meta;statusDefinitions", "mushroombody_SynapseSet;SynapseSet", "pre;statusLabel;status;alpha1;bodyId;mushroombody_Neuron;roiInfo;post;type;instance;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;type;instance;status;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;bodyId;size", "pre;roiInfo;post;Segment;mushroombody_Segment;alpha3;bodyId;size", "pre;statusLabel;status;cropped;bodyId;mushroombody_Neuron;roiInfo;post;type;instance;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;alpha3;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;type;instance;status;Segment;cropped;Neuron;alpha3;mushroombody_Segment;bodyId;size", "pre;statusLabel;roiInfo;post;instance;status;Segment;mushroombody_Segment;alpha3;bodyId;size", "Segment;pre;mushroombody_Segment;roiInfo;post;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;status;Segment;mushroombody_Segment;Neuron;bodyId;size", "pre;statusLabel;status;cropped;alpha1;bodyId;mushroombody_Neuron;roiInfo;post;type;instance;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;size", "pre;statusLabel;roiInfo;post;instance;status;Segment;mushroombody_Segment;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;bodyId;size", "pre;statusLabel;roiInfo;post;status;Segment;mushroombody_Segment;alpha3;bodyId;size", "pre;statusLabel;roiInfo;post;instance;status;Segment;cropped;mushroombody_Segment;bodyId;size", "pre;statusLabel;roiInfo;post;status;Segment;mushroombody_Segment;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;status;Segment;mushroombody_Segment;Neuron;alpha1;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;status;Segment;mushroombody_Segment;Neuron;alpha3;bodyId;size", "pre;statusLabel;roiInfo;post;instance;status;Segment;cropped;mushroombody_Segment;alpha3;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;cropped;Neuron;alpha3;alpha2;mushroombody_Segment;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;alpha2;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;alpha1;bodyId;size", "confidence;Synapse;alpha3;type;mushroombody_Synapse;location", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;status;Segment;cropped;Neuron;mushroombo ...

# %% [markdown]
# ## We can observe that with threshold=0.5, there's still correct cluster, it means 0.5 can be used as a threshold to merge cluster.  if threshold is higher 0.9, there's no more correct clusters formed

# %%
sim_matrix = mb6_sc.nodetypeset.mergeByJaccardSim(return_sim_matrix=True,idf=False)
sim_matrix = np.matrix(sim_matrix)
sim_matrix[sim_matrix>0.5] = 1
sim_matrix[sim_matrix<=0.5] = 0

plot_mb6(sim_matrix,'no idf, with 0.5 as threshold')
# Out:
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="700347ce-da1f-4bc2-975e-2ce57cb745ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("700347ce-da1f-4bc2-975e-2ce57cb745ec")) {                    Plotly.newPlot(                        "700347ce-da1f-4bc2-975e-2ce57cb745ec",                        [{"marker": {"color": ["blue", "yellow", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "red", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "red", "red", "red"]}, "mode": "markers", "text": ["postHighAccuracyThreshold;superLevelRois;logo;neuroglancerMeta;roiHierarchy;postHPThreshold;preHPThreshold;totalPreCount;uuid;roiInfo;neuroglancerInfo;totalPostCount;Meta;meshHost;lastDatabaseEdit;dataset;primaryRois;latestMutationId;medulla7column_Meta;statusDefinitions", "mushroombody_SynapseSet;SynapseSet", "pre;statusLabel;status;alpha1;bodyId;mushroombody_Neuron;roiInfo;post;type;instance;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;type;instance;status;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;bodyId;size", "pre;roiInfo;post;Segment;mushroombody_Segment;alpha3;bodyId;size", "pre;statusLabel;status;cropped;bodyId;mushroombody_Neuron;roiInfo;post;type;instance;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;alpha3;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;type;instance;status;Segment;cropped;Neuron;alpha3;mushroombody_Segment;bodyId;size", "pre;statusLabel;roiInfo;post;instance;status;Segment;mushroombody_Segment;alpha3;bodyId;size", "Segment;pre;mushroombody_Segment;roiInfo;post;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;status;Segment;mushroombody_Segment;Neuron;bodyId;size", "pre;statusLabel;status;cropped;alpha1;bodyId;mushroombody_Neuron;roiInfo;post;type;instance;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;size", "pre;statusLabel;roiInfo;post;instance;status;Segment;mushroombody_Segment;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;bodyId;size", "pre;statusLabel;roiInfo;post;status;Segment;mushroombody_Segment;alpha3;bodyId;size", "pre;statusLabel;roiInfo;post;instance;status;Segment;cropped;mushroombody_Segment;bodyId;size", "pre;statusLabel;roiInfo;post;status;Segment;mushroombody_Segment;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;status;Segment;mushroombody_Segment;Neuron;alpha1;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;status;Segment;mushroombody_Segment;Neuron;alpha3;bodyId;size", "pre;statusLabel;roiInfo;post;instance;status;Segment;cropped;mushroombody_Segment;alpha3;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;cropped;Neuron;alpha3;alpha2;mushroombody_Segment;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;alpha2;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;alpha1;bodyId;size", "confidence;Synapse;alpha3;type;mushroombody_Synapse;location", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;status;Segment;cropped;Neuron;mushroombo ...

# %%
sim_matrix = mb6_sc.nodetypeset.mergeByJaccardSim(return_sim_matrix=True,idf=False)
sim_matrix = np.matrix(sim_matrix)


plot_mb6(sim_matrix=None,title='cosine', metric='cosine')
# Out:
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="81db27d4-51b3-4050-8eae-390dcdd2eece" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81db27d4-51b3-4050-8eae-390dcdd2eece")) {                    Plotly.newPlot(                        "81db27d4-51b3-4050-8eae-390dcdd2eece",                        [{"marker": {"color": ["blue", "yellow", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "red", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "red", "red", "red"]}, "mode": "markers", "text": ["postHighAccuracyThreshold;superLevelRois;logo;neuroglancerMeta;roiHierarchy;postHPThreshold;preHPThreshold;totalPreCount;uuid;roiInfo;neuroglancerInfo;totalPostCount;Meta;meshHost;lastDatabaseEdit;dataset;primaryRois;latestMutationId;medulla7column_Meta;statusDefinitions", "mushroombody_SynapseSet;SynapseSet", "pre;statusLabel;status;alpha1;bodyId;mushroombody_Neuron;roiInfo;post;type;instance;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;type;instance;status;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;bodyId;size", "pre;roiInfo;post;Segment;mushroombody_Segment;alpha3;bodyId;size", "pre;statusLabel;status;cropped;bodyId;mushroombody_Neuron;roiInfo;post;type;instance;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;alpha3;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;type;instance;status;Segment;cropped;Neuron;alpha3;mushroombody_Segment;bodyId;size", "pre;statusLabel;roiInfo;post;instance;status;Segment;mushroombody_Segment;alpha3;bodyId;size", "Segment;pre;mushroombody_Segment;roiInfo;post;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;status;Segment;mushroombody_Segment;Neuron;bodyId;size", "pre;statusLabel;status;cropped;alpha1;bodyId;mushroombody_Neuron;roiInfo;post;type;instance;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;size", "pre;statusLabel;roiInfo;post;instance;status;Segment;mushroombody_Segment;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;bodyId;size", "pre;statusLabel;roiInfo;post;status;Segment;mushroombody_Segment;alpha3;bodyId;size", "pre;statusLabel;roiInfo;post;instance;status;Segment;cropped;mushroombody_Segment;bodyId;size", "pre;statusLabel;roiInfo;post;status;Segment;mushroombody_Segment;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;status;Segment;mushroombody_Segment;Neuron;alpha1;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;status;Segment;mushroombody_Segment;Neuron;alpha3;bodyId;size", "pre;statusLabel;roiInfo;post;instance;status;Segment;cropped;mushroombody_Segment;alpha3;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;cropped;Neuron;alpha3;alpha2;mushroombody_Segment;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;alpha2;bodyId;size", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;instance;status;Segment;mushroombody_Segment;Neuron;alpha3;alpha2;alpha1;bodyId;size", "confidence;Synapse;alpha3;type;mushroombody_Synapse;location", "pre;statusLabel;mushroombody_Neuron;roiInfo;post;status;Segment;cropped;Neuron;mushroombo ...

# %%
srcN_edges_map, tarN_edges_map = mb6_sc.getNodeEdgeMap()
sim_matrix, src_mat, tar_mat  = \
    mb6_sc.nodetypeset.mergeBySimAndEdge(srcN_edges_map,tarN_edges_map,return_sim_matrix=True)

node_matrix = np.array(sim_matrix)
src_mat = np.array(src_mat)
tar_mat = np.array(tar_mat)
# sim_matrix, src_mat, tar_mat = mb6_sc.nodetypeset.mergeBySimAndEdge(return_sim_matrix=True,idf=False)
# sim_matrix = np.matrix(sim_matrix)
avg_matrix = (node_matrix+src_mat+tar_mat) / 3

plot_mb6(sim_matrix=src_mat,title='edge src')
plot_mb6(sim_matrix=tar_mat,title='edge tar')
plot_mb6(sim_matrix=node_matrix,title='node matrix')
plot_mb6(sim_matrix=avg_matrix,title='avg tar')
# Out:
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="b5309500-bbc3-4c75-ae90-94a851702a37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5309500-bbc3-4c75-ae90-94a851702a37")) {                    Plotly.newPlot(                        "b5309500-bbc3-4c75-ae90-94a851702a37",                        [{"marker": {"color": ["blue", "yellow", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "red", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "red", "red", "red"]}, "mode": "markers", "text": ["primaryRois;postHPThreshold;statusDefinitions;logo;superLevelRois;roiInfo;latestMutationId;preHPThreshold;lastDatabaseEdit;medulla7column_Meta;totalPostCount;roiHierarchy;dataset;Meta;neuroglancerMeta;totalPreCount;uuid;neuroglancerInfo;postHighAccuracyThreshold;meshHost", "mushroombody_SynapseSet;SynapseSet", "post;pre;statusLabel;Segment;roiInfo;alpha2;type;bodyId;instance;status;mushroombody_Segment;size;alpha3;Neuron;mushroombody_Neuron;alpha1", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;alpha2;type;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "size;post;pre;alpha3;Segment;roiInfo;mushroombody_Segment;bodyId", "post;pre;statusLabel;Segment;roiInfo;alpha2;type;cropped;bodyId;instance;status;size;alpha3;Neuron;mushroombody_Neuron;mushroombody_Segment", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;type;Neuron;mushroombody_Neuron;cropped;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;mushroombody_Segment;bodyId;instance", "size;post;pre;mushroombody_Segment;bodyId;Segment;roiInfo", "status;size;post;pre;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId", "post;pre;statusLabel;Segment;roiInfo;alpha2;type;cropped;bodyId;instance;status;mushroombody_Segment;size;alpha3;Neuron;mushroombody_Neuron;alpha1", "status;size;post;pre;statusLabel;Segment;roiInfo;mushroombody_Segment;bodyId;instance", "status;size;post;pre;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;mushroombody_Segment;bodyId", "status;size;post;pre;statusLabel;Segment;roiInfo;cropped;mushroombody_Segment;bodyId;instance", "status;size;post;pre;statusLabel;Segment;roiInfo;mushroombody_Segment;bodyId", "status;mushroombody_Segment;size;post;pre;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;alpha1;bodyId", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;cropped;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;alpha2;Neuron;mushroombody_Neuron;cropped;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;alpha2;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "status;size;post;pre;statusLabel;Segment;roiInfo;alpha2;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "status;mushroombody_Segment;size;post;pre;alpha3;statusLabel;Segment;roiInfo;alpha2;Neuron;mushroombody_Neuron;alpha1;bodyId;instance", "Synapse;type;alpha3;mushroombody_Synapse;confidence;location", "status;size;post;pre;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;cropped;mushr ...
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="f4378855-c1da-4b37-9f2a-046cfad5e9f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f4378855-c1da-4b37-9f2a-046cfad5e9f8")) {                    Plotly.newPlot(                        "f4378855-c1da-4b37-9f2a-046cfad5e9f8",                        [{"marker": {"color": ["blue", "yellow", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "red", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "red", "red", "red"]}, "mode": "markers", "text": ["primaryRois;postHPThreshold;statusDefinitions;logo;superLevelRois;roiInfo;latestMutationId;preHPThreshold;lastDatabaseEdit;medulla7column_Meta;totalPostCount;roiHierarchy;dataset;Meta;neuroglancerMeta;totalPreCount;uuid;neuroglancerInfo;postHighAccuracyThreshold;meshHost", "mushroombody_SynapseSet;SynapseSet", "post;pre;statusLabel;Segment;roiInfo;alpha2;type;bodyId;instance;status;mushroombody_Segment;size;alpha3;Neuron;mushroombody_Neuron;alpha1", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;alpha2;type;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "size;post;pre;alpha3;Segment;roiInfo;mushroombody_Segment;bodyId", "post;pre;statusLabel;Segment;roiInfo;alpha2;type;cropped;bodyId;instance;status;size;alpha3;Neuron;mushroombody_Neuron;mushroombody_Segment", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;type;Neuron;mushroombody_Neuron;cropped;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;mushroombody_Segment;bodyId;instance", "size;post;pre;mushroombody_Segment;bodyId;Segment;roiInfo", "status;size;post;pre;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId", "post;pre;statusLabel;Segment;roiInfo;alpha2;type;cropped;bodyId;instance;status;mushroombody_Segment;size;alpha3;Neuron;mushroombody_Neuron;alpha1", "status;size;post;pre;statusLabel;Segment;roiInfo;mushroombody_Segment;bodyId;instance", "status;size;post;pre;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;mushroombody_Segment;bodyId", "status;size;post;pre;statusLabel;Segment;roiInfo;cropped;mushroombody_Segment;bodyId;instance", "status;size;post;pre;statusLabel;Segment;roiInfo;mushroombody_Segment;bodyId", "status;mushroombody_Segment;size;post;pre;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;alpha1;bodyId", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;cropped;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;alpha2;Neuron;mushroombody_Neuron;cropped;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;alpha2;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "status;size;post;pre;statusLabel;Segment;roiInfo;alpha2;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "status;mushroombody_Segment;size;post;pre;alpha3;statusLabel;Segment;roiInfo;alpha2;Neuron;mushroombody_Neuron;alpha1;bodyId;instance", "Synapse;type;alpha3;mushroombody_Synapse;confidence;location", "status;size;post;pre;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;cropped;mushr ...
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="6980f20a-a161-416a-baa2-20652d14d2cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6980f20a-a161-416a-baa2-20652d14d2cf")) {                    Plotly.newPlot(                        "6980f20a-a161-416a-baa2-20652d14d2cf",                        [{"marker": {"color": ["blue", "yellow", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "red", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "red", "red", "red"]}, "mode": "markers", "text": ["primaryRois;postHPThreshold;statusDefinitions;logo;superLevelRois;roiInfo;latestMutationId;preHPThreshold;lastDatabaseEdit;medulla7column_Meta;totalPostCount;roiHierarchy;dataset;Meta;neuroglancerMeta;totalPreCount;uuid;neuroglancerInfo;postHighAccuracyThreshold;meshHost", "mushroombody_SynapseSet;SynapseSet", "post;pre;statusLabel;Segment;roiInfo;alpha2;type;bodyId;instance;status;mushroombody_Segment;size;alpha3;Neuron;mushroombody_Neuron;alpha1", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;alpha2;type;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "size;post;pre;alpha3;Segment;roiInfo;mushroombody_Segment;bodyId", "post;pre;statusLabel;Segment;roiInfo;alpha2;type;cropped;bodyId;instance;status;size;alpha3;Neuron;mushroombody_Neuron;mushroombody_Segment", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;type;Neuron;mushroombody_Neuron;cropped;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;mushroombody_Segment;bodyId;instance", "size;post;pre;mushroombody_Segment;bodyId;Segment;roiInfo", "status;size;post;pre;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId", "post;pre;statusLabel;Segment;roiInfo;alpha2;type;cropped;bodyId;instance;status;mushroombody_Segment;size;alpha3;Neuron;mushroombody_Neuron;alpha1", "status;size;post;pre;statusLabel;Segment;roiInfo;mushroombody_Segment;bodyId;instance", "status;size;post;pre;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;mushroombody_Segment;bodyId", "status;size;post;pre;statusLabel;Segment;roiInfo;cropped;mushroombody_Segment;bodyId;instance", "status;size;post;pre;statusLabel;Segment;roiInfo;mushroombody_Segment;bodyId", "status;mushroombody_Segment;size;post;pre;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;alpha1;bodyId", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;cropped;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;alpha2;Neuron;mushroombody_Neuron;cropped;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;alpha2;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "status;size;post;pre;statusLabel;Segment;roiInfo;alpha2;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "status;mushroombody_Segment;size;post;pre;alpha3;statusLabel;Segment;roiInfo;alpha2;Neuron;mushroombody_Neuron;alpha1;bodyId;instance", "Synapse;type;alpha3;mushroombody_Synapse;confidence;location", "status;size;post;pre;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;cropped;mushr ...
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="68c3751f-3aef-4535-a28f-81c953feaa7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68c3751f-3aef-4535-a28f-81c953feaa7a")) {                    Plotly.newPlot(                        "68c3751f-3aef-4535-a28f-81c953feaa7a",                        [{"marker": {"color": ["blue", "yellow", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "red", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "black", "red", "red", "red"]}, "mode": "markers", "text": ["primaryRois;postHPThreshold;statusDefinitions;logo;superLevelRois;roiInfo;latestMutationId;preHPThreshold;lastDatabaseEdit;medulla7column_Meta;totalPostCount;roiHierarchy;dataset;Meta;neuroglancerMeta;totalPreCount;uuid;neuroglancerInfo;postHighAccuracyThreshold;meshHost", "mushroombody_SynapseSet;SynapseSet", "post;pre;statusLabel;Segment;roiInfo;alpha2;type;bodyId;instance;status;mushroombody_Segment;size;alpha3;Neuron;mushroombody_Neuron;alpha1", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;alpha2;type;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "size;post;pre;alpha3;Segment;roiInfo;mushroombody_Segment;bodyId", "post;pre;statusLabel;Segment;roiInfo;alpha2;type;cropped;bodyId;instance;status;size;alpha3;Neuron;mushroombody_Neuron;mushroombody_Segment", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;type;Neuron;mushroombody_Neuron;cropped;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;mushroombody_Segment;bodyId;instance", "size;post;pre;mushroombody_Segment;bodyId;Segment;roiInfo", "status;size;post;pre;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId", "post;pre;statusLabel;Segment;roiInfo;alpha2;type;cropped;bodyId;instance;status;mushroombody_Segment;size;alpha3;Neuron;mushroombody_Neuron;alpha1", "status;size;post;pre;statusLabel;Segment;roiInfo;mushroombody_Segment;bodyId;instance", "status;size;post;pre;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;mushroombody_Segment;bodyId", "status;size;post;pre;statusLabel;Segment;roiInfo;cropped;mushroombody_Segment;bodyId;instance", "status;size;post;pre;statusLabel;Segment;roiInfo;mushroombody_Segment;bodyId", "status;mushroombody_Segment;size;post;pre;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;alpha1;bodyId", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;cropped;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;alpha2;Neuron;mushroombody_Neuron;cropped;mushroombody_Segment;bodyId;instance", "status;size;post;pre;alpha3;statusLabel;Segment;roiInfo;alpha2;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "status;size;post;pre;statusLabel;Segment;roiInfo;alpha2;Neuron;mushroombody_Neuron;mushroombody_Segment;bodyId;instance", "status;mushroombody_Segment;size;post;pre;alpha3;statusLabel;Segment;roiInfo;alpha2;Neuron;mushroombody_Neuron;alpha1;bodyId;instance", "Synapse;type;alpha3;mushroombody_Synapse;confidence;location", "status;size;post;pre;statusLabel;Segment;roiInfo;Neuron;mushroombody_Neuron;cropped;mushr ...

# %%
srcN_edges_map, tarN_edges_map = sc.getNodeEdgeMap()
sim_matrix, src_mat, tar_mat  = \
    sc.nodetypeset.mergeBySimAndEdge(srcN_edges_map,tarN_edges_map,return_sim_matrix=True)

node_matrix = np.array(sim_matrix)
src_mat = np.array(src_mat)
tar_mat = np.array(tar_mat)
# sim_matrix, src_mat, tar_mat = mb6_sc.nodetypeset.mergeBySimAndEdge(return_sim_matrix=True,idf=False)
# sim_matrix = np.matrix(sim_matrix)
avg_matrix = (node_matrix+src_mat+tar_mat) / 3

plot_snb(sim_matrix=src_mat,title='edge src')
plot_snb(sim_matrix=tar_mat,title='edge tar')
plot_snb(sim_matrix=node_matrix,title='node matrix')
plot_snb(sim_matrix=avg_matrix,title='avg tar')
# Out:
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="5c92d778-67a0-463a-9255-53e84af804ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5c92d778-67a0-463a-9255-53e84af804ee")) {                    Plotly.newPlot(                        "5c92d778-67a0-463a-9255-53e84af804ee",                        [{"marker": {"color": ["#a6cee3", "#1f78b4", "#b2df8a", "#33a02c", "#fb9a99", "#e31a1c", "#e31a1c", "#fdbf6f", "#ff7f00", "#cab2d6", "#6a3d9a", "#ffff99"]}, "mode": "markers", "text": ["Organisation;Company;name;url;id", "locationIP;creationDate;Message;content;id;length;Comment;browserUsed", "Organisation;University;name;url;id", "url;id;Tag;name", "url;id;TagClass;name", "locationIP;creationDate;Message;content;id;length;browserUsed;language;Post", "locationIP;creationDate;Message;id;length;browserUsed;Post;imageFile", "Place;name;Country;url;id", "City;Place;name;url;id", "Place;Continent;name;url;id", "Forum;creationDate;title;id", "lastName;locationIP;creationDate;id;email;firstName;birthday;gender;browserUsed;speaks;Person"], "type": "scatter", "x": [5.310528755187988, 136.30465698242188, 101.1905517578125, -106.82486724853516, -44.365760803222656, 43.884090423583984, 114.0939712524414, -119.72714233398438, -49.51820755004883, -141.93873596191406, 38.731544494628906, -10.944339752197266], "y": [171.04965209960938, 23.800941467285156, -84.98519134521484, 148.84173583984375, 78.63272094726562, 73.4740219116211, 135.9330291748047, -72.07717895507812, -9.617324829101562, 40.05521011352539, -14.776019096374512, -107.19334411621094]}],                        {"plot_bgcolor": "rgba(0,0,0,0)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46 ...
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="dde4206f-23cd-417a-b97c-dd6abeb1d375" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dde4206f-23cd-417a-b97c-dd6abeb1d375")) {                    Plotly.newPlot(                        "dde4206f-23cd-417a-b97c-dd6abeb1d375",                        [{"marker": {"color": ["#a6cee3", "#1f78b4", "#b2df8a", "#33a02c", "#fb9a99", "#e31a1c", "#e31a1c", "#fdbf6f", "#ff7f00", "#cab2d6", "#6a3d9a", "#ffff99"]}, "mode": "markers", "text": ["Organisation;Company;name;url;id", "locationIP;creationDate;Message;content;id;length;Comment;browserUsed", "Organisation;University;name;url;id", "url;id;Tag;name", "url;id;TagClass;name", "locationIP;creationDate;Message;content;id;length;browserUsed;language;Post", "locationIP;creationDate;Message;id;length;browserUsed;Post;imageFile", "Place;name;Country;url;id", "City;Place;name;url;id", "Place;Continent;name;url;id", "Forum;creationDate;title;id", "lastName;locationIP;creationDate;id;email;firstName;birthday;gender;browserUsed;speaks;Person"], "type": "scatter", "x": [5.310528755187988, 136.30465698242188, 101.1905517578125, -106.82486724853516, -44.365760803222656, 43.884090423583984, 114.0939712524414, -119.72714233398438, -49.51820755004883, -141.93873596191406, 38.731544494628906, -10.944339752197266], "y": [171.04965209960938, 23.800941467285156, -84.98519134521484, 148.84173583984375, 78.63272094726562, 73.4740219116211, 135.9330291748047, -72.07717895507812, -9.617324829101562, 40.05521011352539, -14.776019096374512, -107.19334411621094]}],                        {"plot_bgcolor": "rgba(0,0,0,0)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46 ...
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="f92b6d78-a5fb-40dc-8b3d-3703d7ed9b8b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f92b6d78-a5fb-40dc-8b3d-3703d7ed9b8b")) {                    Plotly.newPlot(                        "f92b6d78-a5fb-40dc-8b3d-3703d7ed9b8b",                        [{"marker": {"color": ["#a6cee3", "#1f78b4", "#b2df8a", "#33a02c", "#fb9a99", "#e31a1c", "#e31a1c", "#fdbf6f", "#ff7f00", "#cab2d6", "#6a3d9a", "#ffff99"]}, "mode": "markers", "text": ["Organisation;Company;name;url;id", "locationIP;creationDate;Message;content;id;length;Comment;browserUsed", "Organisation;University;name;url;id", "url;id;Tag;name", "url;id;TagClass;name", "locationIP;creationDate;Message;content;id;length;browserUsed;language;Post", "locationIP;creationDate;Message;id;length;browserUsed;Post;imageFile", "Place;name;Country;url;id", "City;Place;name;url;id", "Place;Continent;name;url;id", "Forum;creationDate;title;id", "lastName;locationIP;creationDate;id;email;firstName;birthday;gender;browserUsed;speaks;Person"], "type": "scatter", "x": [5.310528755187988, 136.30465698242188, 101.1905517578125, -106.82486724853516, -44.365760803222656, 43.884090423583984, 114.0939712524414, -119.72714233398438, -49.51820755004883, -141.93873596191406, 38.731544494628906, -10.944339752197266], "y": [171.04965209960938, 23.800941467285156, -84.98519134521484, 148.84173583984375, 78.63272094726562, 73.4740219116211, 135.9330291748047, -72.07717895507812, -9.617324829101562, 40.05521011352539, -14.776019096374512, -107.19334411621094]}],                        {"plot_bgcolor": "rgba(0,0,0,0)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46 ...
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="14a9123a-6cc4-4dec-8092-8d6d725cf907" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("14a9123a-6cc4-4dec-8092-8d6d725cf907")) {                    Plotly.newPlot(                        "14a9123a-6cc4-4dec-8092-8d6d725cf907",                        [{"marker": {"color": ["#a6cee3", "#1f78b4", "#b2df8a", "#33a02c", "#fb9a99", "#e31a1c", "#e31a1c", "#fdbf6f", "#ff7f00", "#cab2d6", "#6a3d9a", "#ffff99"]}, "mode": "markers", "text": ["Organisation;Company;name;url;id", "locationIP;creationDate;Message;content;id;length;Comment;browserUsed", "Organisation;University;name;url;id", "url;id;Tag;name", "url;id;TagClass;name", "locationIP;creationDate;Message;content;id;length;browserUsed;language;Post", "locationIP;creationDate;Message;id;length;browserUsed;Post;imageFile", "Place;name;Country;url;id", "City;Place;name;url;id", "Place;Continent;name;url;id", "Forum;creationDate;title;id", "lastName;locationIP;creationDate;id;email;firstName;birthday;gender;browserUsed;speaks;Person"], "type": "scatter", "x": [5.310528755187988, 136.30465698242188, 101.1905517578125, -106.82486724853516, -44.365760803222656, 43.884090423583984, 114.0939712524414, -119.72714233398438, -49.51820755004883, -141.93873596191406, 38.731544494628906, -10.944339752197266], "y": [171.04965209960938, 23.800941467285156, -84.98519134521484, 148.84173583984375, 78.63272094726562, 73.4740219116211, 135.9330291748047, -72.07717895507812, -9.617324829101562, 40.05521011352539, -14.776019096374512, -107.19334411621094]}],                        {"plot_bgcolor": "rgba(0,0,0,0)", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46 ...

# %%
def plotMb6Edge(sim_matrix,title='edge similarity'):
    tsne = TSNE(n_components=2, random_state=0,metric='precomputed')
    X_2d = tsne.fit_transform(1-sim_matrix.toarray())
    labels = mb6_sc.edgetypeset.getListOfEdgeInfo()
    layout = go.Layout(
        plot_bgcolor='rgba(0,0,0,0)'
    )
    # get color
    edge_types = [['Segment','Contains'],['SynapsesTo'],['Contains','Synapse'],
                  ['SynapseSet','ConnectsTo'],
                 ['ConnectsTo','mushroombody_Segment']]
    color_list = []
    colomap = getRandomColor(5)
    for edge_pattern in labels:
        lbl_li = edge_pattern.split(',')
        append = 0
        for ind,lblset in enumerate(edge_types):
            cnt = 0
            for indi_lbl in lblset:
                if indi_lbl in lbl_li:
                    cnt += 1 
            if cnt == len(lblset):
                color_list.append(colomap[ind])
                append = 1 
    fig = go.Figure(data=go.Scatter(x=X_2d[:, 0],
                                    y=X_2d[:, 1],
                                    mode='markers',
                                    marker_color=color_list,
                                    text=labels),
                                    layout=layout) # hover text goes here

    fig.update_layout(title=title)
    fig.show()
src_matrix,tar_matrix,edge_matrix = mb6_sc.edgetypeset.mergeByEdgeSim()
plotMb6Edge(src_matrix,title='edge patterns with src similarity')
plotMb6Edge(tar_matrix,title='edge patterns with target similarity')
plotMb6Edge(edge_matrix,title='edge patterns with edge similarity')
plotMb6Edge((src_matrix+tar_matrix+edge_matrix)/3, title='avg similarity edge patterns')
# Out:
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="84946093-255d-4df4-9669-92c61a2f8a64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("84946093-255d-4df4-9669-92c61a2f8a64")) {                    Plotly.newPlot(                        "84946093-255d-4df4-9669-92c61a2f8a64",                        [{"marker": {"color": ["#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20ECC4", "#20 ...
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="13527a4d-9a90-47ff-84d3-56e0f5ba1b11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13527a4d-9a90-47ff-84d3-56e0f5ba1b11")) {                    Plotly.newPlot(                        "13527a4d-9a90-47ff-84d3-56e0f5ba1b11",                        [{"marker": {"color": ["#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43639F", "#43 ...
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="8c0104fd-d5cc-4654-81da-82bc796521b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c0104fd-d5cc-4654-81da-82bc796521b5")) {                    Plotly.newPlot(                        "8c0104fd-d5cc-4654-81da-82bc796521b5",                        [{"marker": {"color": ["#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5B5FF", "#A5 ...
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="cb66fcd8-9e79-48d4-ac02-ca15b051ddf8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb66fcd8-9e79-48d4-ac02-ca15b051ddf8")) {                    Plotly.newPlot(                        "cb66fcd8-9e79-48d4-ac02-ca15b051ddf8",                        [{"marker": {"color": ["#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27D2EB", "#27 ...

# %%
sim_matrix = sc.edgetypeset.mergeByEdgeSim().toarray()
tsne = TSNE(n_components=2, random_state=0,metric='precomputed')
X_2d = tsne.fit_transform(1-sim_matrix/3)
labels = sc.edgetypeset.getListOfEdgeInfo()
layout = go.Layout(
    plot_bgcolor='rgba(0,0,0,0)'
)
fig = go.Figure(data=go.Scatter(x=X_2d[:, 0],
                                y=X_2d[:, 1],
                                mode='markers',
#                                 marker_color=snb_color,
                                text=labels),
                                layout=layout) # hover text goes here

fig.update_layout(title='snb edge jaccard simliarity, each point is an edge pattern')
fig.show()
# Out:
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="2b1c7801-759b-4153-aa3f-5fca76ebbefa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b1c7801-759b-4153-aa3f-5fca76ebbefa")) {                    Plotly.newPlot(                        "2b1c7801-759b-4153-aa3f-5fca76ebbefa",                        [{"mode": "markers", "text": ["edge: IS_LOCATED_IN\n|src: Comment,length,Message,id,content,locationIP,creationDate,browserUsed\n|tar: url,id,name,Country,Place", "edge: IS_LOCATED_IN\n|src: email,speaks,id,Person,birthday,firstName,locationIP,creationDate,gender,browserUsed,lastName\n|tar: url,id,name,City,Place", "edge: KNOWS,creationDate\n|src: email,speaks,id,Person,birthday,firstName,locationIP,creationDate,gender,browserUsed,lastName\n|tar: email,speaks,id,Person,birthday,firstName,locationIP,creationDate,gender,browserUsed,lastName", "edge: IS_LOCATED_IN\n|src: language,length,Message,id,content,Post,locationIP,creationDate,browserUsed\n|tar: url,id,name,Country,Place", "edge: IS_LOCATED_IN\n|src: length,Message,id,Post,locationIP,creationDate,browserUsed,imageFile\n|tar: url,id,name,Country,Place", "edge: IS_LOCATED_IN\n|src: url,Organisation,id,Company,name\n|tar: url,id,name,Country,Place", "edge: IS_LOCATED_IN\n|src: url,Organisation,id,name,University\n|tar: url,id,name,City,Place", "edge: REPLY_OF\n|src: Comment,length,Message,id,content,locationIP,creationDate,browserUsed\n|tar: Comment,length,Message,id,content,locationIP,creationDate,browserUsed", "edge: LIKES,creationDate\n|src: email,speaks,id,Person,birthday,firstName,locationIP,creationDate,gender,browserUsed,lastName\n|tar: length,Message,id,Post,locationIP,creationDate,browserUsed,imageFile", "edge: LIKES,creationDate\n|src: email,speaks,id,Person,birthday,firstName,locationIP,creationDate,gender,browserUsed,lastName\n|tar: language,length,Message,id,content,Post,locationIP,creationDate,browserUsed", "edge: REPLY_OF\n|src: Comment,length,Message,id,content,locationIP,creationDate,browserUsed\n|tar: language,length,Message,id,content,Post,locationIP,creationDate,browserUsed", "edge: STUDY_AT,classYear\n|src: email,speaks,id,Person,birthday,firstName,locationIP,creationDate,gender,browserUsed,lastName\n|tar: url,Organisation,id,name,University", "edge: LIKES,creationDate\n|src: email,speaks,id,Person,birthday,firstName,locationIP,creationDate,gender,browserUsed,lastName\n|tar: Comment,length,Message,id,content,locationIP,creationDate,browserUsed", "edge: HAS_INTEREST\n|src: email,speaks,id,Person,birthday,firstName,locationIP,creationDate,gender,browserUsed,lastName\n|tar: url,Tag,id,name", "edge: HAS_MEMBER,joinDate\n|src: title,creationDate,id,Forum\n|tar: email,speaks,id,Person,birthday,firstName,locationIP,creationDate,gender,browserUsed,lastName", "edge: HAS_TYPE\n|src: url,Tag,id,name\n|tar: url,TagClass,id,name", "edge: CONTAINER_OF\n|src: title,creationDate,id,Forum\n|tar: language,length,Message,id,content,Post,locationIP,creationDate,browserUsed", "edge: CONTAINER_OF\n|src: title,creationDate,id,Forum\n|tar: length,Message,id,Post,locationIP,creationDate,browserUsed,imageFile", "edge: workFrom,WORK_AT\n|src: email,speaks,id,Person,birthday,firstName,locationIP,creationDate,gender,browserUsed,lastName\n|tar: url,Organisation,id,Company,name", "edge: IS_SUBCLASS_OF\n|src: url,TagClass,id,name\n|tar: url,TagClass,id,name", "edge: HAS_MODERATOR\n|src: title,creationDate,id,Forum\n|tar: email,speaks,id,Person,birthday,firstName,locationIP,creationDate,gender,browserUsed,lastName", "edge: HAS_CREATOR\n|src: Comment,length,Message,id,content,locationIP,creationDate,browserUsed\n|tar: email,speaks,id,Person,birthday,firstName,locationIP,creationDate,gender,browserUsed,lastName", "edge: HAS_CREATOR\n|src: language,length,Message,id,cont ...

# %%
from pickle5 import pickle
shop_sc = pickle.load(open('shop_attr_based_schema.pkl','rb',-1))
x,labels = shop_sc.nodetypeset.plotVectorizedNodes()
sim_matrix = shop_sc.nodetypeset.mergeByJaccardSim(return_sim_matrix=True,idf=False)

# %%
from lxml import etree
from matplotlib.cm import cool
xml_tree = etree.parse('shop_data/shop.xml')
node_labels = [i.text for i in xml_tree.findall(".//types/alias")]
colors = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])
             for i in range(len(node_labels))]
# colors = get_n_colors(len(node_labels))
shop_color = []
for l in labels:
    lb_li = l.split(';')
    cnt = 0
    for i,nl in enumerate(node_labels):
        
        if cnt > 1:
            print(l)
        if nl in lb_li:
            cnt += 1 
            shop_color.append(colors[i])
#             break

# %%
tsne = TSNE(n_components=2, random_state=0,metric='precomputed',perplexity=50)
X_2d = tsne.fit_transform(1-sim_matrix.toarray())
# labels = sc.edgetypeset.getListOfEdgeInfo()
layout = go.Layout(
    plot_bgcolor='rgba(0,0,0,0)'
)
fig = go.Figure(data=go.Scatter(x=X_2d[:, 0],
                                y=X_2d[:, 1],
                                mode='markers',
                                marker_color=shop_color,
                                opacity=0.5,
                                text=labels),
                                layout=layout) # hover text goes here

fig.update_layout(title='shop node jaccard simliarity, each point is an edge pattern,no weighting')
fig.show()
# Out:
# x:\py3\lib\site-packages\sklearn\manifold\_t_sne.py:699: FutureWarning:
#
# 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
# <div>                            <div id="c31823bf-6754-4480-8f60-5e205acbf196" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c31823bf-6754-4480-8f60-5e205acbf196")) {                    Plotly.newPlot(                        "c31823bf-6754-4480-8f60-5e205acbf196",                        [{"marker": {"color": ["#9BEFDD", "#11A784", "#F809AC", "#58E1E2", "#993114", "#48FFA6", "#1C5A5C", "#C50E23", "#E381B6", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#B6149F", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB0533", "#CB ...
